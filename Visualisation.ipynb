# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=pd.read_csv('movies.csv')
a
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
b=pd.read_csv('directors.csv')
b
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
#a['year']=pd.to_datetime(a['year'])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
#df=pd.merge(a,b,left_on='director_id',right_on='id',how='left')
#df

# %%
df=a.merge(b,left_on='director_id',right_on='id',how='left')
df
# Out:
#       Unnamed: 0_x   id_x     budget  popularity     revenue  \
# 0                0  43597  237000000         150  2787965087
# 1                1  43598  300000000         139   961000000
# 2                2  43599  245000000         107   880674609
# 3                3  43600  250000000         112  1084939099
# 4                5  43602  258000000         115   890871626
# ...            ...    ...        ...         ...         ...
# 1460          4736  48363          0           3      321952
# 1461          4743  48370      27000          19     3151130
# 1462          4748  48375          0           7           0
# 1463          4749  48376          0           3           0
# 1464          4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
df.drop(columns=['Unnamed: 0_x','id_x','Unnamed: 0_y','id_y'],inplace=True)

# %%
df
# Out:
#          budget  popularity     revenue  \
# 0     237000000         150  2787965087
# 1     300000000         139   961000000
# 2     245000000         107   880674609
# 3     250000000         112  1084939099
# 4     258000000         115   890871626
# ...         ...         ...         ...
# 1460          0           3      321952
# 1461      27000          19     3151130
# 1462          0           7           0
# 1463          0           3           0
# 1464     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
df['year'].value_counts()
# Out:
# year
# 2006    73
# 2005    71
# 2002    69
# 2008    67
# 2011    67
# 2009    66
# 1999    64
# 2010    63
# 2001    62
# 2004    61
# 2000    59
# 2003    58
# 2013    57
# 2007    54
# 2014    53
# 2012    49
# 1997    46
# 1996    46
# 1998    45
# 2015    41
# 1995    33
# 1994    31
# 2016    26
# 1992    22
# 1989    18
# 1990    18
# 1993    18
# 1985    14
# 1988    13
# 1991    12
# 1987    12
# 1986    11
# 1981    11
# 1982    10
# 1984    10
# 1983     9
# 1980     8
# 1977     6
# 1978     5
# 1979     4
# 1976     3
# Name: count, dtype: int64

# %%
df.sort_values(by='director_name').reset_index(drop=True)
# Out:
#         budget  popularity    revenue  \
# 0     28000000          57  133346506
# 1     65000000          22  128107642
# 2     26000000          29   90574188
# 3     50000000          38  173649015
# 4     72500000          12  162966177
# ...        ...         ...        ...
# 1460       110           9          0
# 1461         0           1          0
# 1462         0          21   92863945
# 1463  31000000          23  177394432
# 1464         0           6          0
#
#                                             title  vote_average  vote_count  \
# 0                                   The Big Short           7.3        2607
# 1                                   Step Brothers           6.5        1062
# 2           Anchorman: The Legend of Ron Burgundy           6.7        1493
# 3               Anchorman 2: The Legend Continues           6.0         923
# 4     Talladega Nights: The Ballad of Ricky Bobby           6.2         491
# ...

# %% [markdown]
# # Bar Graph

# %%
df.groupby('year')['popularity'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,8))
plt.bar(df['year'],df['popularity'],color='r')
plt.title('Popularity of film')
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.grid()
plt.show()

# %% [markdown]
# * the film raleased in 2014 is most popular
# * the popularity of film increases as year goes
# * the popularity of the film is maximum at 2010 and 2015

# %%
director_revenue = df.groupby('director_name')['revenue'].sum().sort_values(ascending=False)
a=director_revenue.head(10)
plt.figure(figsize=(12, 8))
a.plot(kind='bar', color='skyblue')
plt.title('Total Revenue by Director')
plt.xlabel('Director')
plt.ylabel('Total Revenue')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# * the graph shows the comparison of total revenue for each director.
# * the movies directed by Steven Spielberg have maximum revenue

# %%
a['director_name'].value_counts()
# Out:
# director_name
# Christopher Nolan     3
# Gore Verbinski        3
# David Fincher         2
# George Miller         1
# Francis Lawrence      1
# Ridley Scott          1
# Zack Snyder           1
# James Cameron         1
# Jonathan Liebesman    1
# Chris Columbus        1
# Bryan Singer          1
# David Ayer            1
# Robert Zemeckis       1
# Peter Jackson         1
# Rob Marshall          1
# Name: count, dtype: int64

# %% [markdown]
# # Pie Chart

# %%
df.groupby('title')['budget'].sum().sort_values(ascending=False).head(5).plot(kind='pie',autopct='%1.2f%%')
plt.title('Budget range of Movie')
plt.show()

# %% [markdown]
# * this chart shows the top 5 movies with maximum budget
# * Pirates of the Caribbean: On Stranger Tides is top movie with maximum budget

# %%
df['day'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.title('Distribution of movie released  in each day')
# Out:
# Text(0.5, 1.0, 'Distribution of movie released  in each day')

# %% [markdown]
# * This chart shows percentage of movie released in each day
# * most of the filims are released in friday

# %%
plt.boxplot(df['vote_average'])
plt.title('boxplot of average vote')
plt.show()

# %% [markdown]
# * there is so many outliers in this data

# %%
plt.violinplot(df['vote_average'])
plt.show()

# %% [markdown]
# * this data is equally distriuted

# %%
df['director_name'].value_counts().head(10).plot(kind='bar',color='gold')
plt.xticks(rotation=90)
plt.xlabel('Director Name')
plt.ylabel('Count')
plt.title('Count of Movies Directed')
plt.show()

# %% [markdown]
# * Bar graph shows no.of movies directed by director
# * Steven Spielberg directed more number of filim

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(df['year'],df['revenue'])
axes[0].set_title(' Total Revenue')
axes[0].set_xlabel('year')
axes[0].set_ylabel('Revenue')
axes[1].plot(df['year'],df['budget'])
axes[1].set_title('total budget')
axes[1].set_xlabel('year')
axes[1].set_ylabel('Budget')
plt.show()
